# %% [markdown]
# Here is a proof of concept for importing nested folders of MicroCT data and extracting the .log files, then putting it all in a labeled property graph.

# %%
from PIL import Image
from PIL.TiffTags import TAGS
import glob
import os


def extract_meta_dict(glob_str, verbose=False):
    meta_dict = {}
    print("Scanning files ...\n")
    for _file in glob.glob(glob_str):
        if verbose:
            print(f"  - {_file}")
        img = Image.open(_file)
        _meta = {TAGS[key] : img.tag[key] for key in img.tag_v2}
        _fn_short = os.path.basename(_file)
        meta_dict[_fn_short] = _meta
    print("\n... done.")
    return {_k: meta_dict[_k] for _k in sorted(meta_dict)}
    

def extract_tiff_tags(img):
    for _k in img.tag_v2:
        if _k in TAGS.keys():
            print(TAGS[_k], img.tag[_k])
        else:
            print(f"CUSTOM TAG[{_k}]", img.tag[_k])
        print()


def scan_directory_with_meta(base_folder):
    glob_dict = {'folder': {}, 'file': [], 'meta': {}}
    for _f in glob.glob(f"{base_folder}/**", recursive=True):
        _fp = os.path.abspath(_f)
        if os.path.exists(_fp):
            relative_path = _fp[len(os.path.abspath(base_folder)) + 1:].split(os.sep)
            current_level = glob_dict
            for part in relative_path[:-1]:
                if part not in current_level['folder']:
                    current_level['folder'][part] = {'folder': {}, 'file': [], 'meta': {}}
                current_level = current_level['folder'][part]
            if os.path.isdir(_fp):
                if relative_path[-1] not in current_level['folder']:
                    current_level['folder'][relative_path[-1]] = {'folder': {}, 'file': [], 'meta': {}}
            elif os.path.isfile(_fp):
                file_info = {
                    'name': relative_path[-1],
                    'filepath': _fp,
                    'extension': os.path.splitext(_fp)[1],
                    'size': os.path.getsize(_fp)
                }

                current_level['file'].append(file_info)
                if _fp.endswith('.log'):
                    # Parse the log file and store its contents in the 'meta' dictionary
                    current_level['meta'] = parse_log_file(_fp)
    return glob_dict
    

def summarize_and_print_tree(glob_dict, indent_level=0):
    # Print file extension summary for the current folder
    print('')
    extension_count = {}
    for file_info in glob_dict['file']:
        file_name = file_info['name']
        extension = os.path.splitext(file_name)[1]  # Extract file extension
        if extension in extension_count:
            extension_count[extension] += 1
        else:
            extension_count[extension] = 1
    for ext, count in extension_count.items():
        print('    ' * indent_level + f"{ext if ext else '(no extension)'} ({count} files)")
    # Process each folder recursively
    for folder_name, folder_content in glob_dict['folder'].items():
        print('    ' * indent_level + f"+ {folder_name}/")
        summarize_and_print_tree(folder_content, indent_level + 1)


def collect_meta_entries(glob_dict, base_folder, current_path=''):
    meta_entries = {}
    # Check if there's meta data at this level
    if glob_dict['meta']:
        full_path = os.path.join(base_folder, current_path)
        meta_entries[full_path] = glob_dict['meta']

    # Recursively process each subfolder
    for folder_name, folder_content in glob_dict['folder'].items():
        new_path = os.path.join(current_path, folder_name)
        meta_entries.update(collect_meta_entries(folder_content, base_folder, new_path))

    return meta_entries


def parse_log_file(file_path):
    meta_dict = {}
    current_section = None
    try:
        with open(file_path, 'r') as file:
            for line in file:
                line = line.strip()
                if line.startswith('[') and line.endswith(']'):
                    current_section = line[1:-1]
                    meta_dict[current_section] = {}
                elif '=' in line:
                    key, value = line.split('=', 1)
                    if current_section:
                        meta_dict[current_section][key.strip()] = value.strip()
                    else:
                        meta_dict[key.strip()] = value.strip()
    except FileNotFoundError:
        print(f"File not found: {file_path}")
    except Exception as e:
        print(f"Error reading file {file_path}: {e}")
    return meta_dict

# %%
base_folder = 'LaraM new study'
result = scan_directory_with_meta(base_folder)
meta_data = collect_meta_entries(result, base_folder)
summarize_and_print_tree(result)
# Out:
# + /
#
# + Scan1/
#
#     + 2R/
#
#         .tif (558 files)
#         .log (1 files)
#         + 2R_Rec/
#
#             .tif (411 files)
#             + temp/
#
#                 .bmp (1 files)
#                 .tif (3 files)
#                 .log (1 files)
#     + both/
#
#         .tif (558 files)
#         .log (1 files)
#         + both_Rec/
#
#             .tif (459 files)
#             .log (1 files)
#             + temp/
#
#                 .tif (4 files)
#                 .bmp (1 files)
#                 .log (1 files)
#     + none/
#
#         .tif (557 files)
#         .log (1 files)
#         + none_Rec/
#
#             .tif (434 files)
#             + temp/
#
#                 .tif (3 files)
#                 .log (1 files)
#                 .bmp (1 files)
#     + 1R/
#
#         .tif (558 files)
#         .log (1 files)
#         + 1R_Rec/
#
#             .tif (422 files)
#             + temp/
#
#                 .bmp (1 files)
#                 .tif (3 files)
#                 .log (1 files)
#     + 1L/
#
#         .tif (557 files)
#         .log (1 files)
#         + 1L_Rec/
#
#             .tif (471 files)
#             + temp/
#
#                 .tif (3 files)
#                 .bmp (1 files)
#                 .log (1 files)
# + Scan2/
#
#     .png (5 files)
#     + 2R/
#
#         .tif (558 files)
#         .log (1 files)
#         + 2R_Rec/
#
#             .tif (367 files)
#             + temp/
#
#                 .bmp (1 files)
#                 .tif (3 files)
#                 .log (1 files)
#     + 1R/
#
#         .tif (557 files)
#         .log (1 files)
#         + 1R_Rec/
#
#             .tif (482 files)
#             + temp/
#
#                 .bmp (1 files)
#                 .tif (3 files)
#                 .log (1 files)
#     + Both/
#
#         .tif (558 files)
#         .log (1 files)
#         + Both_Rec/
#
#             .tif (393 files)
#             .log (1 files)
#             + temp/
#
#                 .bmp (1 files)
#                 .tif (4 files)
#                 .log (1 files)
#     + None/
#
#         .tif (557 files)
#         .log (1 files)
#         + None_Rec/
#
#             .tif (420 files)
#             + temp/
#
#                 .tif (3 files)
#                 .log (1 files)
#                 .bmp (1 files)
#     + 1L/
#
#         .tif (559 files)
#         .log (1 files)
#         + 1L_Rec/
#
#             .tif (408 files)
#             + temp/
#
#                 .tif (3 files)
#                 .bmp (1 files)
#                 .log (1 files)

# %%
unique_key_sets = set()
for _fp, _scan in meta_data.items():
    unique_key_sets.add(frozenset(_scan.keys()))
for key_set in unique_key_sets:
    print(list(key_set))
# Out:
# ['Acquisition', 'User', 'System', 'Reconstruction', 'File name convention']
# ['Acquisition', 'System', 'Reconstruction', 'User']

# %%
print()
for _k, _v in meta_data['LaraM new study/Scan1/1L'].items():
    print(f" {_k}")
    print()
    for _kk, _vv in _v.items():
        print(f"   {_kk:>50s}:  {_vv}")
    print()
# Out:
#  System
#
#                                               Scanner:  SkyScan1276
#                                        Instrument S/N:  18F17059
#                                      Software Version:  1.4
#                           Magnification Drive Version:  3.4
#                                  Camera Drive Version:  3.4
#                                 Filter  Drive Version:  3.4
#                                  Animal Drive Version:  3.4
#                                        Home Directory:  C:\SkyScan1276
#                                           Source Type:  HAMAMATSU L10321
#                                           Camera Type:  XIMEA MH110XC-KK-TP
#                                Camera Pixel Size (um):  17.359
#                                      Camera X/Y Ratio:  0.9949
#
#  User
#
#                                             User Name:  vspan
#                                         Computer Name:  MICROCT
#
#  Acquisition
#
#                                        Data Directory:  D:\Results\LauraM\new study\1L
#                                       Filename Prefix:  1L
#                                       Number Of Files:  556
#                                        Number Of Rows:  672
#                                     Number Of Columns:  1008
#                                 Filename Index Length:  8
#                                         Partial Width:  OFF
#                                   Image crop origin X:  0
#                                   Image crop origin Y:  0
#                                        Camera binning:  4x4
#                                        Image Rotation:  0.00000
#                                   Optical Axis (line):  346
#                                 Object to Source (mm):  92.863
#                                 Camera to Source (mm):  160.543
#                                   Source Voltage (kV):  100
#                                   Source Current (uA):  200
#                                 Image Pixel Size (um):  40.164000
#                          Scaled Image Pixel Size (um):  40.164000
#                                          Image Format:  TIFF
#                                          Depth (bits):  16
#                                   Reference Intensity:  58000
#                                         Exposure (ms):  90
#                                   Rotation Step (deg):  0.649
#                                      Use 360 Rotation:  YES
#                                     Scanning position:  243.750 mm
#                                       Frame Averaging:  OFF (1)
#                                 Flat Field Correction:  ON
#                                       Random Movement:  OFF (5)
#                                                Filter:  Al 0.5mm
#                                      Gantry direction:  CC
#                                    Rotation Direction:  CC
#                       Intrinsic CS rotation in degree:  180.0
#                               Type of Detector Motion:  CONTINUOUS
#                                        Rotation speed:  1
#                                   Scanning Trajectory:  ROUND
#                            Suggested HU - Calibration:  180000
#                 Number Of Horizontal Offset Positions:  1
#                                   Study Date and Time:  18 Sep 2020  10h:42m:13s
#                                         Scan duration:  0h:1m:16s
#                                   Maximum vertical TS:  5.0
#
#  Reconstruction
#
#                                Reconstruction Program:  NRecon
#                                       Program Version:  Version: 1.7.4.2
#                                Program Home Directory:  C:\SkyScan1276
#                                 Reconstruction engine:  GPUReconServer
#                                        Engine version:  Version: 1.7.4
#                             Reconstruction from batch:  No
#                                 Postalignment Applied:  1
#                                         Postalignment:  0.50
#                                Reconstruction servers:  MICROCT
#                                        Dataset Origin:  SkyScan1276
#                                        Dataset Prefix:  1L
#                                     Dataset Directory:  D:\Results\LauraM\new study\1L
#                                      Output Directory:  D:\Results\LauraM\new study\1L\1L_Rec
#                                         Time and Date:  Sep 18, 2020  10:45:03
#                                         First Section:  132
#                                          Last Section:  602
#           Reconstruction duration per slice (seconds):  0.199575
#     Total reconstruction time (471 slices) in seconds:  94.000000
#                               Section to Section Step:  1
#                                        Sections Count:  471
#                                      Result File Type:  TIF
#                     Result File Header Length (bytes):  12
#                           Result Image Width (pixels):  616
#                          Result Image Height (pixels):  532
#                                       Pixel Size (um):  40.16400
#                    Reconstruction Angular Range (deg):  360.84
#                                              Use 180+:  OFF
#                                    Angular Step (deg):  0.6490
#                                             Smoothing:  2
#                                      Smoothing kernel:  2 (Gaussian)
#                              Ring Artifact Correction:  2
#                                           Draw Scales:  OFF
#                                Object Bigger than FOV:  ON
#                               Reconstruction from ROI:  ON
#                                      ROI Top (pixels):  977
#                                   ROI Bottom (pixels):  444
#                                     ROI Left (pixels):  231
#                                    ROI Right (pixels):  847
#                                  ROI reference length:  1008
#           Filter cutoff relative to Nyquist frequency:  100
#                                           Filter type:  0
#                               Filter type description:  Hamming (Alpha=0.54)
#                                  Undersampling factor:  1
#                   Threshold for defect pixel mask (%):  0
#                         Beam Hardening Correction (%):  33
#                              CS Static Rotation (deg):  0.00
#                         CS Static Rotation Total(deg):  180.00
#                    Minimum for CS to Image Conversion:  0.000000
#                    Maximum for CS to Image Conversion:  0.015000
#                                        HU Calibration:  OFF
#                                               BMP LUT:  0
#                           Cone-beam Angle Horiz.(deg):  24.594404
#                            Cone-beam Angle Vert.(deg):  16.536995

# %% [raw]
# meta_data

# %%
result['folder']['Scan1']['folder'].keys()
# Out:
# dict_keys(['2R', 'both', 'none', '1R', '1L'])

# %%
from neomodel import StructuredNode, StringProperty, RelationshipTo, IntegerProperty, RelationshipFrom

class Folder(StructuredNode):
    name = StringProperty()
    filepath = StringProperty(index=True)
    contains_folder = RelationshipTo('Folder', 'CONTAINS_FOLDER')
    contained_by = RelationshipFrom('Folder', 'CONTAINS_FOLDER')
    contains_file = RelationshipTo('File', 'CONTAINS_FILE')

class File(StructuredNode):
    name = StringProperty()
    filepath = StringProperty(index=True)
    extension = StringProperty()
    size = IntegerProperty()
    contained_by = RelationshipFrom('Folder', 'CONTAINS_FILE')

class Scan(StructuredNode):
    filepath = StringProperty(index=True)
    stored_in = RelationshipTo('Folder', 'STORED_IN')
    involved = RelationshipTo('Section', 'INVOLVED')

class Section(StructuredNode):
    name = StringProperty(unique_index=True)
    involved_in = RelationshipFrom('Scan', 'INVOLVED')


import os
import networkx as nx

def build_graph(data_dict, base_folder):
    G = nx.DiGraph()
    base_path = os.path.abspath(base_folder)

    def process_folder(current_dict, parent_id=None):
        """Recursively process each folder and file in the current dictionary."""
        for folder_path, folder_content in current_dict['folder'].items():
            folder_id = f"folder_{folder_path}"
            folder_absolute_path = os.path.join(base_path, folder_path)
            G.add_node(folder_id, label='Folder', name=folder_path, filepath=folder_absolute_path)
            
            # Establish a containment relationship with the parent folder
            if parent_id:
                G.add_edge(parent_id, folder_id, relationship='contains_folder')

            # Process files in the folder
            process_files(folder_content['file'], folder_id)

            # Recurse into subfolders
            process_folder(folder_content, folder_id)

            # Process metadata associated with the folder
            process_metadata(folder_content['meta'], folder_id, folder_absolute_path)

    def process_files(files, parent_folder_id):
        """Add file nodes and establish relationships to the containing folder."""
        for file_info in files:
            file_id = f"file_{file_info['filepath']}"
            G.add_node(file_id, label='File', **file_info)
            G.add_edge(parent_folder_id, file_id, relationship='contains_file')

    def process_metadata(meta_dict, folder_id, folder_path):
        """Add metadata nodes and establish involved relationships."""
        if meta_dict:
            for section, attrs in meta_dict.items():
                section_id = f"{section}_{folder_path}"
                _properties = {
                    to_lower_camel_case(convert_chars_for_neo4j(_k)): _v
                    for _k, _v in attrs.items()
                }
                G.add_node(section_id, label=section, **_properties)
                scan_id = f"scan_{folder_path}"
                G.add_node(scan_id, label='Scan', filepath=folder_path)
                G.add_edge(scan_id, section_id, relationship='involved')
                G.add_edge(scan_id, folder_id, relationship='stored_in')

    # Start processing from the top-level dictionary
    process_folder(data_dict)

    return G

import re

def to_lower_camel_case(s):
    s = re.sub(r"(_|-)+", " ", s).title().replace(" ", "")
    return s[0].lower() + s[1:]

def convert_chars_for_neo4j(s):
    s = s.replace('/','')
    s = s.replace('(','_')
    s = s.replace(')','_')
    s = s.replace('+','plus')
    return s

def collect_properties_by_meta_section(nx_graph):
    schema_labels = ['Folder', 'File', 'Scan'] 
    meta_section_labels = []
    for node, data in nx_graph.nodes(data=True):
        label = data['label']
        if label not in schema_labels and label not in meta_section_labels:
            meta_section_labels.append(label)

    props_by_section = {}    
    for section in meta_section_labels:
        props_by_section[section] = set()
        for node, data in nx_graph.nodes(data=True):
            label = data['label']
            if label == section:
                for _k, _v in data.items():
                    if _k != 'label':
                        props_by_section[section].add(_k)

    return {_s: list(_p) for _s, _p in props_by_section.items()}, meta_section_labels, schema_labels

from neomodel import StructuredNode, StringProperty, db
from tqdm import tqdm

def initialize_class_map_from_graph(nx_graph, meta_section_properties):
    sections = meta_section_properties.keys()
    class_map = {'Folder': Folder, 'File': File, 'Scan': Scan, 'Section': Section}
    
    # Create Neomodel classes for each unique section label found
    for section_name in meta_section_properties.keys():
        # for node, data in nx_graph.nodes(data=True):
        #     label = data['label']            
        class_key = section_name.replace(' ', '_')
        if class_key not in class_map:
            class_map[class_key] = type(class_key, (Section,), {
                _p: StringProperty(unique_index=True) 
                for _p in meta_section_properties[section_name]
            })
            
    return class_map

# %%
# Example usage
# Assuming 'result' is your data dictionary structured as expected
G = build_graph(result,'LaraM new study/')

# %%
def find_nodes_by_label(label):
    for node, data in G.nodes(data=True):
        if data['label'] == label:
            print(node)
            print(data)
            print()

# %%
find_nodes_by_label('Acquisition')
# Out:
# Acquisition_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/temp
# {'label': 'Acquisition', 'dataDirectory': 'D:\\Results\\LauraM\\new study\\Scan2\\1L', 'filenamePrefix': '1L', 'numberOfFiles': '558', 'numberOfRows': '672', 'numberOfColumns': '1008', 'filenameIndexLength': '8', 'partialWidth': 'OFF', 'imageCropOriginX': '0', 'imageCropOriginY': '0', 'cameraBinning': '4x4', 'imageRotation': '0.00000', 'opticalAxisLine': '346', 'objectToSourceMm': '92.863', 'cameraToSourceMm': '160.543', 'sourceVoltageKv': '100', 'sourceCurrentUa': '200', 'imagePixelSizeUm': '40.164000', 'scaledImagePixelSizeUm': '40.164000', 'imageFormat': 'TIFF', 'depthBits': '16', 'referenceIntensity': '58000', 'exposureMs': '90', 'rotationStepDeg': '0.648', 'use360Rotation': 'YES', 'scanningPosition': '241.306 mm', 'frameAveraging': 'OFF (1)', 'flatFieldCorrection': 'ON', 'randomMovement': 'OFF (5)', 'filter': 'Al 0.5mm', 'gantryDirection': 'CC', 'rotationDirection': 'CC', 'intrinsicCsRotationInDegree': '180.0', 'typeOfDetectorMotion': 'CONTINUOUS', 'rotationSpeed': '1', 'scanningTrajectory': 'ROUND', 'suggestedHuCalibration': '180000', 'numberOfHorizontalOffsetPositions': '1', 'studyDateAndTime': '25 Sep 2020  13h:09m:23s', 'scanDuration': '0h:1m:16s', 'maximumVerticalTs': '5.0'}
#
# Acquisition_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/2R
# {'label': 'Acquisition', 'dataDirectory': 'D:\\Results\\LauraM\\new study\\Scan2\\2R', 'filenamePrefix': '2R', 'numberOfFiles': '557', 'numberOfRows': '672', 'numberOfColumns': '1008', 'filenameIndexLength': '8', 'partialWidth': 'OFF', 'imageCropOriginX': '0', 'imageCropOriginY': '0', 'cameraBinning': '4x4', 'imageRotation': '0.00000', 'opticalAxisLine': '346', 'objectToSourceMm': '92.863', 'cameraToSourceMm': '160.543', 'sourceVoltageKv': '100', 'sourceCurrentUa': '200', 'imagePixelSizeUm': '40.164000', 'scaledImagePixelSizeUm': '40.164000', 'imageFormat': 'TIFF', 'depthBits': '16', 'referenceIntensity': '58000', 'exposureMs': '90', 'rotationStepDeg': '0.648', 'use360Rotation': 'YES', 'scanningPosition': '240.000 mm', 'frameAveraging': 'OFF (1)', 'flatFieldCorrection': 'ON', 'randomMovement': 'OFF (5)', 'filter': 'Al 0.5mm', 'gantryDirection': 'CC', 'rotationDirection': 'CC', 'intrinsicCsRotationInDegree': '180.0', 'typeOfDetectorMotion': 'CONTINUOUS', 'rotationSpeed': '1', 'scanningTrajectory': 'ROUND', 'suggestedHuCalibration': '180000', 'numberOfHorizontalOffsetPositions': '1', 'studyDateAndTime': '25 Sep 2020  13h:02m:33s', 'scanDuration': '0h:1m:16s', 'maximumVerticalTs': '5.0'}
#
# Acquisition_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/both_Rec
# {'label': 'Acquisition', 'dataDirectory': 'D:\\Results\\LauraM\\new study\\both', 'filenamePrefix': 'both', 'numberOfFiles': '557', 'numberOfRows': '672', 'numberOfColumns': '1008', 'filenameIndexLength': '8', 'partialWidth': 'OFF', 'imageCropOriginX': '0', 'imageCropOriginY': '0', 'cameraBinning': '4x4', 'imageRotation': '0.00000', 'opticalAxisLine': '346', 'objectToSourceMm': '92.863', 'cameraToSourceMm': '160.543', 'sourceVoltageKv': '100', 'sourceCurrentUa': '200', 'imagePixelSizeUm': '40.164000', 'scaledImagePixelSizeUm': '40.164000', 'imageFormat': 'TIFF', 'depthBits': '16', 'referenceIntensity': '58000', 'exposureMs': '90', 'rotationStepDeg': '0.649', 'use360Rotation': 'YES', 'scanningPosition': '244.000 mm', 'frameAveraging': 'OFF (1)', 'flatFieldCorrection': 'ON', 'randomMovement': 'OFF (5)', 'filter': 'Al 0.5mm', 'gantryDirection': 'CC', 'rotationDirection': 'CC', 'intrinsicCsRotationInDegree': '180.0', 'typeOfDetectorMotion': 'CONTINUOUS', 'rotationSpeed': '1', 'scanningTrajectory': 'ROUND', 'suggestedHuCalibration': '180000', 'numberOfHorizontalOffsetPositions': '1', 'studyDateAndTime': '18 Sep 2020  11h:02m:45s', 'scanDuration': '0h:1m:15s', 'maximumVerticalTs': '5.0'}
#
# Acquisition_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/both
# {'label': 'Acquisition', 'dataDirectory': 'D:\\Results\\LauraM\\new study\\both', 'filenamePrefix': 'both', 'numberOfFiles': '557', 'numberOfRows': '672', 'numberOfColumns': '1008', 'filenameIndexLength': '8', 'partialWidth': 'OFF', 'imageCropOriginX': '0', 'imageCropOriginY': '0', 'cameraBinning': '4x4', 'imageRotation': '0.00000', 'opticalAxisLine': '346', 'objectToSourceMm': '92.863', 'cameraToSourceMm': '160.543', 'sourceVoltageKv': '100', 'sourceCurrentUa': '200', 'imagePixelSizeUm': '40.164000', 'scaledImagePixelSizeUm': '40.164000', 'imageFormat': 'TIFF', 'depthBits': '16', 'referenceIntensity': '58000', 'exposureMs': '90', 'rotationStepDeg': '0.649', 'use360Rotation': 'YES', 'scanningPosition': '244.000 mm', 'frameAveraging': 'OFF (1)', 'flatFieldCorrection': 'ON', 'randomMovement': 'OFF (5)', 'filter': 'Al 0.5mm', 'gantryDirection': 'CC', 'rotationDirection': 'CC', 'intrinsicCsRotationInDegree': '180.0', 'typeOfDetectorMotion': 'CONTINUOUS', 'rotationSpeed': '1', 'scanningTrajectory': 'ROUND', 'suggestedHuCalibration': '180000', 'numberOfHorizontalOffsetPositions': '1', 'studyDateAndTime': '18 Sep 2020  11h:02m:45s', 'scanDuration': '0h:1m:15s', 'maximumVerticalTs': '5.0'}
#
# Acquisition_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/none
# {'label': 'Acquisition', 'dataDirectory': 'D:\\Results\\LauraM\\new study\\none', 'filenamePrefix': 'none', 'numberOfFiles': '556', 'numberOfRows': '672', 'numberOfColumns': '1008', 'filenameIndexLength': '8', 'partialWidth': 'OFF', 'imageCropOriginX': '0', 'imageCropOriginY': '0', 'cameraBinning': '4x4', 'imageRotation': '0.00000', 'opticalAxisLine': '346', 'objectToSourceMm': '92.863', 'cameraToSourceMm': '160.543', 'sourceVoltageKv': '100', 'sourceCurrentUa': '200', 'imagePixelSizeUm': '40.164000', 'scaledImagePixelSizeUm': '40.164000', 'imageFormat': 'TIFF', 'depthBits': '16', 'referenceIntensity': '58000', 'exposureMs': '90', 'rotationStepDeg': '0.649', 'use360Rotation': 'YES', 'scanningPosition': '244.000 mm', 'frameAveraging': 'OFF (1)', 'flatFieldCorrection': 'ON', 'randomMovement': 'OFF (5)', 'filter': 'Al 0.5mm', 'gantryDirection': 'CC', 'rotationDirection': 'CC', 'intrinsicCsRotationInDegree': '180.0', 'typeOfDetectorMotion': 'CONTINUOUS', 'rotationSpeed': '1', 'scanningTrajectory': 'ROUND', 'suggestedHuCalibration': '180000', 'numberOfHorizontalOffsetPositions': '1', 'studyDateAndTime': '18 Sep 2020  10h:47m:21s', 'scanDuration': '0h:1m:15s', 'maximumVerticalTs': '5.0'}
#
# Acquisition_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/1R
# {'label': 'Acquisition', 'dataDirectory': 'D:\\Results\\LauraM\\new study\\Scan2\\1R', 'filenamePrefix': '1R', 'numberOfFiles': '556', 'numberOfRows': '672', 'numberOfColumns': '1008', 'filenameIndexLength': '8', 'partialWidth': 'OFF', 'imageCropOriginX': '0', 'imageCropOriginY': '0', 'cameraBinning': '4x4', 'imageRotation': '0.00000', 'opticalAxisLine': '346', 'objectToSourceMm': '92.863', 'cameraToSourceMm': '160.543', 'sourceVoltageKv': '100', 'sourceCurrentUa': '200', 'imagePixelSizeUm': '40.164000', 'scaledImagePixelSizeUm': '40.164000', 'imageFormat': 'TIFF', 'depthBits': '16', 'referenceIntensity': '58000', 'exposureMs': '90', 'rotationStepDeg': '0.649', 'use360Rotation': 'YES', 'scanningPosition': '238.706 mm', 'frameAveraging': 'OFF (1)', 'flatFieldCorrection': 'ON', 'randomMovement': 'OFF (5)', 'filter': 'Al 0.5mm', 'gantryDirection': 'CC', 'rotationDirection': 'CC', 'intrinsicCsRotationInDegree': '180.0', 'typeOfDetectorMotion': 'CONTINUOUS', 'rotationSpeed': '1', 'scanningTrajectory': 'ROUND', 'suggestedHuCalibration': '180000', 'numberOfHorizontalOffsetPositions': '1', 'studyDateAndTime': '25 Sep 2020  12h:49m:53s', 'scanDuration': '0h:1m:15s', 'maximumVerticalTs': '5.0'}
#
# Acquisition_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/1L
# {'label': 'Acquisition', 'dataDirectory': 'D:\\Results\\LauraM\\new study\\Scan2\\1L', 'filenamePrefix': '1L', 'numberOfFiles': '558', 'numberOfRows': '672', 'numberOfColumns': '1008', 'filenameIndexLength': '8', 'partialWidth': 'OFF', 'imageCropOriginX': '0', 'imageCropOriginY': '0', 'cameraBinning': '4x4', 'imageRotation': '0.00000', 'opticalAxisLine': '346', 'objectToSourceMm': '92.863', 'cameraToSourceMm': '160.543', 'sourceVoltageKv': '100', 'sourceCurrentUa': '200', 'imagePixelSizeUm': '40.164000', 'scaledImagePixelSizeUm': '40.164000', 'imageFormat': 'TIFF', 'depthBits': '16', 'referenceIntensity': '58000', 'exposureMs': '90', 'rotationStepDeg': '0.648', 'use360Rotation': 'YES', 'scanningPosition': '241.306 mm', 'frameAveraging': 'OFF (1)', 'flatFieldCorrection': 'ON', 'randomMovement': 'OFF (5)', 'filter': 'Al 0.5mm', 'gantryDirection': 'CC', 'rotationDirection': 'CC', 'intrinsicCsRotationInDegree': '180.0', 'typeOfDetectorMotion': 'CONTINUOUS', 'rotationSpeed': '1', 'scanningTrajectory': 'ROUND', 'suggestedHuCalibration': '180000', 'numberOfHorizontalOffsetPositions': '1', 'studyDateAndTime': '25 Sep 2020  13h:09m:23s', 'scanDuration': '0h:1m:16s', 'maximumVerticalTs': '5.0'}
#
# Acquisition_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Both_Rec
# {'label': 'Acquisition', 'dataDirectory': 'D:\\Results\\LauraM\\new study\\Scan2\\Both', 'filenamePrefix': 'Both', 'numberOfFiles': '557', 'numberOfRows': '672', 'numberOfColumns': '1008', 'filenameIndexLength': '8', 'partialWidth': 'OFF', 'imageCropOriginX': '0', 'imageCropOriginY': '0', 'cameraBinning': '4x4', 'imageRotation': '0.00000', 'opticalAxisLine': '346', 'objectToSourceMm': '92.863', 'cameraToSourceMm': '160.543', 'sourceVoltageKv': '100', 'sourceCurrentUa': '200', 'imagePixelSizeUm': '40.164000', 'scaledImagePixelSizeUm': '40.164000', 'imageFormat': 'TIFF', 'depthBits': '16', 'referenceIntensity': '58000', 'exposureMs': '90', 'rotationStepDeg': '0.649', 'use360Rotation': 'YES', 'scanningPosition': '244.325 mm', 'frameAveraging': 'OFF (1)', 'flatFieldCorrection': 'ON', 'randomMovement': 'OFF (5)', 'filter': 'Al 0.5mm', 'gantryDirection': 'CC', 'rotationDirection': 'CC', 'intrinsicCsRotationInDegree': '180.0', 'typeOfDetectorMotion': 'CONTINUOUS', 'rotationSpeed': '1', 'scanningTrajectory': 'ROUND', 'suggestedHuCalibration': '180000', 'numberOfHorizontalOffsetPositions': '1', 'studyDateAndTime': '25 Sep 2020  13h:14m:02s', 'scanDuration': '0h:1m:16s', 'maximumVerticalTs': '5.0'}
#
# Acquisition_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Both
# {'label': 'Acquisition', 'dataDirectory': 'D:\\Results\\LauraM\\new study\\Scan2\\Both', 'filenamePrefix': 'Both', 'numberOfFiles': '557', 'numberOfRows': '672', 'numberOfColumns': '1008', 'filenameIndexLength': '8', 'partialWidth': 'OFF', 'imageCropOriginX': '0', 'imageCropOriginY': '0', 'cameraBinning': '4x4', 'imageRotation': '0.00000', 'opticalAxisLine': '346', 'objectToSourceMm': '92.863', 'cameraToSourceMm': '160.543', 'sourceVoltageKv': '100', 'sourceCurrentUa': '200', 'imagePixelSizeUm': '40.164000', 'scaledImagePixelSizeUm': '40.164000', 'imageFormat': 'TIFF', 'depthBits': '16', 'referenceIntensity': '58000', 'exposureMs': '90', 'rotationStepDeg': '0.649', 'use360Rotation': 'YES', 'scanningPosition': '244.325 mm', 'frameAveraging': 'OFF (1)', 'flatFieldCorrection': 'ON', 'randomMovement': 'OFF (5)', 'filter': 'Al 0.5mm', 'gantryDirection': 'CC', 'rotationDirection': 'CC', 'intrinsicCsRotationInDegree': '180.0', 'typeOfDetectorMotion': 'CONTINUOUS', 'rotationSpeed': '1', 'scanningTrajectory': 'ROUND', 'suggestedHuCalibration': '180000', 'numberOfHorizontalOffsetPositions': '1', 'studyDateAndTime': '25 Sep 2020  13h:14m:02s', 'scanDuration': '0h:1m:16s', 'maximumVerticalTs': '5.0'}
#
# Acquisition_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/None
# {'label': 'Acquisition', 'dataDirectory': 'D:\\Results\\LauraM\\new study\\Scan2\\None', 'filenamePrefix': 'None', 'numberOfFiles': '556', 'numberOfRows': '672', 'numberOfColumns': '1008', 'filenameIndexLength': '8', 'partialWidth': 'OFF', 'imageCropOriginX': '0', 'imageCropOriginY': '0', 'cameraBinning': '4x4', 'imageRotation': '0.00000', 'opticalAxisLine': '346', 'objectToSourceMm': '92.863', 'cameraToSourceMm': '160.543', 'sourceVoltageKv': '100', 'sourceCurrentUa': '200', 'imagePixelSizeUm': '40.164000', 'scaledImagePixelSizeUm': '40.164000', 'imageFormat': 'TIFF', 'depthBits': '16', 'referenceIntensity': '58000', 'exposureMs': '90', 'rotationStepDeg': '0.649', 'use360Rotation': 'YES', 'scanningPosition': '238.169 mm', 'frameAveraging': 'OFF (1)', 'flatFieldCorrection': 'ON', 'randomMovement': 'OFF (5)', 'filter': 'Al 0.5mm', 'gantryDirection': 'CC', 'rotationDirection': 'CC', 'intrinsicCsRotationInDegree': '180.0', 'typeOfDetectorMotion': 'CONTINUOUS', 'rotationSpeed': '1', 'scanningTrajectory': 'ROUND', 'suggestedHuCalibration': '180000', 'numberOfHorizontalOffsetPositions': '1', 'studyDateAndTime': '25 Sep 2020  12h:55m:30s', 'scanDuration': '0h:1m:16s', 'maximumVerticalTs': '5.0'}

# %%
from ..labdataranger.model import

# %% [raw]
# from neomodel import config, db
#
# import ..labdataranger as ldr
#
# ldr.store.neomodel_db_config(database='instruments')
#
# # config.DATABASE_URL = f'bolt://{username}:{password}@ki-ed3g.mit.edu:7687/instruments'
#
#
# with db.transaction:
#     folder1 = Folder(name="Folder1", filepath="/path1").save()
#     folder2 = Folder(name="Folder2", filepath="/path2").save()
#     folder1.contains_folder.connect(folder2)
#
#     file1 = File(name="File1", filepath="/file1").save()
#     folder2.contains_file.connect(file1)

# %%
node_list = list(G.nodes(data=True))
len(node_list), node_list[:3]
# Out:
# (9982,
#  [('folder_',
#    {'label': 'Folder',
#     'name': '',
#     'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/'}),
#   ('folder_Scan1',
#    {'label': 'Folder',
#     'name': 'Scan1',
#     'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1'}),
#   ('folder_2R',
#    {'label': 'Folder',
#     'name': '2R',
#     'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/2R'})])

# %%
edge_list = list(G.edges(data=True))
len(edge_list), edge_list[:3]
# Out:
# (9988,
#  [('folder_Scan1', 'folder_2R', {'relationship': 'contains_folder'}),
#   ('folder_Scan1', 'folder_both', {'relationship': 'contains_folder'}),
#   ('folder_Scan1', 'folder_none', {'relationship': 'contains_folder'})])

# %%
meta_section_properties, meta_section_labels, schema_labels = collect_properties_by_meta_section(G)
class_map = initialize_class_map_from_graph(G, meta_section_properties)
class_map
# Out:
# {'Folder': __main__.Folder,
#  'File': __main__.File,
#  'Scan': __main__.Scan,
#  'Section': __main__.Section,
#  'System': neomodel.sync_.core.System,
#  'User': neomodel.sync_.core.User,
#  'Acquisition': neomodel.sync_.core.Acquisition,
#  'Reconstruction': neomodel.sync_.core.Reconstruction,
#  'File_name_convention': neomodel.sync_.core.File_name_convention}

# %%
def list_class_attributes(model_class):
    print("Attributes:")
    for attr in dir(model_class):
        if not attr.startswith("__") and not callable(getattr(model_class, attr)):
            print(f"{attr}: {getattr(model_class, attr)}")

# Example usage
list_class_attributes(class_map['Acquisition'])
# Out:
# Attributes:
# cameraBinning: <neomodel.properties.StringProperty object at 0x73e414184f70>
# cameraToSourceMm: <neomodel.properties.StringProperty object at 0x73e4141844c0>
# dataDirectory: <neomodel.properties.StringProperty object at 0x73e414184fd0>
# depthBits: <neomodel.properties.StringProperty object at 0x73e41408a820>
# element_id: <property object at 0x73e33bcb45e0>
# exposureMs: <neomodel.properties.StringProperty object at 0x73e41408ab80>
# filenameIndexLength: <neomodel.properties.StringProperty object at 0x73e414184e80>
# filenamePrefix: <neomodel.properties.StringProperty object at 0x73e414184f40>
# filter: <neomodel.properties.StringProperty object at 0x73e414184ee0>
# flatFieldCorrection: <neomodel.properties.StringProperty object at 0x73e414184e20>
# frameAveraging: <neomodel.properties.StringProperty object at 0x73e41408aeb0>
# gantryDirection: <neomodel.properties.StringProperty object at 0x73e41408af70>
# id: <property object at 0x73e33bcb4630>
# imageCropOriginX: <neomodel.properties.StringProperty object at 0x73e414184fa0>
# imageCropOriginY: <neomodel.properties.StringProperty object at 0x73e41408abe0>
# imageFormat: <neomodel.properties.StringProperty object at 0x73e41408af10>
# imagePixelSizeUm: <neomodel.properties.StringProperty object at 0x73e41408aac0>
# imageRotation: <neomodel.properties.StringProperty object at 0x73e41408a5e0>
# intrinsicCsRotationInDegree: <neomodel.properties.StringProperty object at 0x73e41408a7c0>
# involved_in: <neomodel.sync_.relationship_manager.RelationshipFrom object at 0x73e33bcc9a60>
# maximumVerticalTs: <neomodel.properties.StringProperty object at 0x73e41408a5b0>
# name: <neomodel.properties.StringProperty object at 0x73e33bcc9c40>
# nodes: <neomodel.sync_.match.NodeSet object at 0x73e4051c97c0>
# numberOfColumns: <neomodel.properties.StringProperty object at 0x73e414184550>
# numberOfFiles: <neomodel.properties.StringProperty object at 0x73e4141845b0>
# numberOfHorizontalOffsetPositions: <neomodel.properties.StringProperty object at 0x73e41408ad60>
# numberOfRows: <neomodel.properties.StringProperty object at 0x73e41408adc0>
# objectToSourceMm: <neomodel.properties.StringProperty object at 0x73e414184df0>
# opticalAxisLine: <neomodel.properties.StringProperty object at 0x73e41408ac70>
# partialWidth: <neomodel.properties.StringProperty object at 0x73e41408acd0>
# randomMovement: <neomodel.properties.StringProperty object at 0x73e414184e50>
# referenceIntensity: <neomodel.properties.StringProperty object at 0x73e414184dc0>
# rotationDirection: <neomodel.properties.StringProperty object at 0x73e41408ad30>
# rotationSpeed: <neomodel.properties.StringProperty object at 0x73e414184eb0>
# rotationStepDeg: <neomodel.properties.StringProperty object at 0x73e41408aee0>
# scaledImagePixelSizeUm: <neomodel.properties.StringProperty object at 0x73e41408a880>
# scanDuration: <neomodel.properties.StringProperty object at 0x73e414184520>
# scanningPosition: <neomodel.properties.StringProperty object at 0x73e41408ac10>
# scanningTrajectory: <neomodel.properties.StringProperty object at 0x73e41408ae50>
# sourceCurrentUa: <neomodel.properties.StringProperty object at 0x73e414184790>
# sourceVoltageKv: <neomodel.properties.StringProperty object at 0x73e41408a9a0>
# studyDateAndTime: <neomodel.properties.StringProperty object at 0x73e41408ad90>
# suggestedHuCalibration: <neomodel.properties.StringProperty object at 0x73e414184730>
# typeOfDetectorMotion: <neomodel.properties.StringProperty object at 0x73e41408a970>
# use360Rotation: <neomodel.properties.StringProperty object at 0x73e414184f10>
# was_saved: <property object at 0x73e33bcb4680>

# %%
from tqdm import tqdm

def load_networkx_to_neo4j(nx_graph, class_map):
    node_map = {}

    with db.transaction:
        for node, data in tqdm(nx_graph.nodes(data=True), desc="Nodes"):
            label = data['label']
            properties = {
                k: v 
                for k, v in data.items() if k not in ['label', 'relationship']
            }
            
            NodeClass = class_map.get(label, None)
            if NodeClass:
                node_instance = NodeClass(**properties).save()
                node_map[node] = node_instance
            else:
                label_mod = to_lower_camel_case(convert_chars_for_neo4j(label))
                NodeClass = class_map.get(label_mod, None)
                if NodeClass:
                    node_instance = NodeClass(**properties).save()
                    node_map[node] = node_instance
                else:
                    print(f"WARNING: Node {node} was not matched with a label... contains:")
                    print(f"         {data}")

        for source, target, data in tqdm(nx_graph.edges(data=True), desc="Edges"):
            relationship_type = data.get('relationship')
            source_node = node_map.get(source)
            target_node = node_map.get(target)
            
            if source_node and target_node and relationship_type:
                # relationship = getattr(source_node, relationship_type, None)
                source_type = nx_graph.nodes[source]['label']
                relationship = getattr(class_map[source_type], relationship_type, None)
                if relationship:
                    getattr(source_node, relationship_type).connect(target_node)
                else:
                    print(f"Relationship type '{relationship_type}' not found between {source} and {target}")

    # TODO: I am still manually removing the "Section" label afterwards, but this could be a final step here

    print("Graph loading complete!")
    return node_map

# %%
len(list(G.nodes()))
# Out:
# 9982

# %%
len(list(G.edges()))
# Out:
# 9988

# %%
list(G.nodes(data=True))[:1]
# Out:
# [('folder_',
#   {'label': 'Folder',
#    'name': '',
#    'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/'})]

# %%
from neomodel import config
import ..labdataranger as ldr

ldr.store.neomodel_db_config(database='instruments')

# config.DATABASE_URL = f'bolt://{username}:{password}@ki-ed3g.mit.edu:7687/instruments'
node_map = load_networkx_to_neo4j(G, class_map)
# Out:
# aenter called
# Nodes:  12%|███▋                          | 1237/9982 [00:01<00:07, 1131.01it/s]
# WARNING: Node File name convention_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/temp was not matched with a label... contains:
#          {'label': 'File name convention', 'filenameIndexLength': '8', 'filenamePrefix': '1L_rec'}
# Nodes: 100%|██████████████████████████████| 9982/9982 [00:05<00:00, 1704.40it/s]
# Edges: 100%|██████████████████████████████| 9988/9988 [00:04<00:00, 2078.77it/s]
# aexit called
# Graph loading complete!

# %%
for source, target, data in tqdm(G.edges(data=True), desc="Edges"):
    relationship_type = data.get('relationship')
    source_node = node_map.get(source)
    target_node = node_map.get(target)
    print(f"  Source: {source_node}")
    print(f"  Target: {target_node}")
    print(f" RelType: {relationship_type}")
    if source_node and target_node and relationship_type:
        relationship = getattr(source_node, relationship_type, None)


    if source_node and target_node and relationship_type:
        relationship = getattr(source_node, relationship_type, None)
        print()
        print(f"       Relationship: {relationship}")
        break
# Out:
# Edges:   0%|                                           | 0/9988 [00:00<?, ?it/s]
#   Source: {'name': 'Scan1', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1', 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:18068'}
#   Target: {'name': '2R', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/2R', 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:18069'}
#  RelType: contains_folder
#
#        Relationship: zero or more relationships in a outgoing direction of type CONTAINS_FOLDER on node (4:31534542-ba07-4b86-8482-b4daf2237641:18068) of class 'Folder'

# %%
source_node, target_node
# Out:
# (<Folder: {'name': 'Scan1', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1', 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:18068'}>,
#  <Folder: {'name': '2R', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/2R', 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:18069'}>)

# %%
relationship_type
# Out:
# 'contains_folder'

# %%
source_type = G.nodes(data=True)[source]['label']
class_map = {'Folder': Folder, 'File': File, 'Scan': Scan, 'Section': Section}
getattr(class_map.get(source_type), relationship_type, None)

# %%
getattr(source_node['label'], relationship_type, None)

# %% [raw]
# for source, target, data in tqdm(G.edges(data=True), desc="Edges"):
#     relationship_type = data.get('relationship')
#     source_node = G.nodes()[source]['label']
#     target_node = G.nodes()[target]['label']
#     print(f"  Source: {source_node}")
#     print(f"  Target: {target_node}")
#     print(f" RelType: {relationship_type}")
#     # if source_node and target_node and relationship_type:
#     #     relationship = getattr(source_node, relationship_type, None)
#     #     print()
#     #     print(f"  Relationship Type: {relationship_type}")
#     #     print(f"       Relationship: {relationship}")
#     #     if relationship:
#     #         source_node.relationship.connect(target_node)
#     #     else:
#     #         print(f"Relationship type '{relationship_type}' not found between {source} and {target}")

# %%
for node, data in tqdm(G.nodes(data=True), desc="Nodes"):
    print(node_map.get(node))
    break
# Out:
# Nodes:   0%|                                           | 0/9982 [00:00<?, ?it/s]
# {'name': '', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/', 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58945'}

# %%
node_map[]
# Out:
# {'folder_': <Folder: {'name': '', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/', 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58945'}>,
#  'folder_Scan1': <Folder: {'name': 'Scan1', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1', 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58946'}>,
#  'folder_2R': <Folder: {'name': '2R', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/2R', 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58947'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000083.tif': <File: {'name': '2R00000083.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000083.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58948'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000250.tif': <File: {'name': '2R00000250.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000250.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58949'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000246.tif': <File: {'name': '2R00000246.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000246.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58950'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000007.tif': <File: {'name': '2R00000007.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000007.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58951'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000115.tif': <File: {'name': '2R00000115.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000115.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58952'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000130.tif': <File: {'name': '2R00000130.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000130.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58953'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000474.tif': <File: {'name': '2R00000474.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000474.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58954'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000556.tif': <File: {'name': '2R00000556.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000556.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58955'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000536.tif': <File: {'name': '2R00000536.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000536.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58956'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000185.tif': <File: {'name': '2R00000185.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000185.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58957'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000117.tif': <File: {'name': '2R00000117.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000117.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58958'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000523.tif': <File: {'name': '2R00000523.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000523.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58959'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000432.tif': <File: {'name': '2R00000432.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000432.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58960'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000512.tif': <File: {'name': '2R00000512.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000512.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58961'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000048.tif': <File: {'name': '2R00000048.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000048.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58962'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000515.tif': <File: {'name': '2R00000515.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000515.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58963'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000483.tif': <File: {'name': '2R00000483.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000483.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58964'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000472.tif': <File: {'name': '2R00000472.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000472.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58965'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000092.tif': <File: {'name': '2R00000092.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000092.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58966'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000392.tif': <File: {'name': '2R00000392.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000392.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58967'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000206.tif': <File: {'name': '2R00000206.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000206.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58968'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000138.tif': <File: {'name': '2R00000138.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000138.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58969'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000350.tif': <File: {'name': '2R00000350.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000350.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58970'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000151.tif': <File: {'name': '2R00000151.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000151.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58971'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000084.tif': <File: {'name': '2R00000084.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000084.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58972'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000019.tif': <File: {'name': '2R00000019.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000019.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58973'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000481.tif': <File: {'name': '2R00000481.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000481.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58974'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000528.tif': <File: {'name': '2R00000528.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000528.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58975'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000132.tif': <File: {'name': '2R00000132.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000132.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58976'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000352.tif': <File: {'name': '2R00000352.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000352.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58977'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000237.tif': <File: {'name': '2R00000237.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000237.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58978'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000061.tif': <File: {'name': '2R00000061.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000061.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58979'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000426.tif': <File: {'name': '2R00000426.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000426.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58980'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000233.tif': <File: {'name': '2R00000233.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000233.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58981'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000031.tif': <File: {'name': '2R00000031.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000031.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58982'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000397.tif': <File: {'name': '2R00000397.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000397.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58983'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000373.tif': <File: {'name': '2R00000373.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000373.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58984'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000417.tif': <File: {'name': '2R00000417.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000417.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58985'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000427.tif': <File: {'name': '2R00000427.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000427.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58986'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000012.tif': <File: {'name': '2R00000012.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000012.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58987'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000155.tif': <File: {'name': '2R00000155.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000155.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58988'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000044.tif': <File: {'name': '2R00000044.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000044.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58989'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000296.tif': <File: {'name': '2R00000296.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000296.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58990'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000113.tif': <File: {'name': '2R00000113.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000113.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58991'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000399.tif': <File: {'name': '2R00000399.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000399.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58992'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000358.tif': <File: {'name': '2R00000358.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000358.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58993'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000270.tif': <File: {'name': '2R00000270.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000270.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58994'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000238.tif': <File: {'name': '2R00000238.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000238.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58995'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000542.tif': <File: {'name': '2R00000542.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000542.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58996'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000088.tif': <File: {'name': '2R00000088.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000088.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58997'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000093.tif': <File: {'name': '2R00000093.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000093.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58998'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000396.tif': <File: {'name': '2R00000396.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000396.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:58999'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000226.tif': <File: {'name': '2R00000226.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000226.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59000'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000017.tif': <File: {'name': '2R00000017.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000017.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59001'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000415.tif': <File: {'name': '2R00000415.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000415.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59002'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000409.tif': <File: {'name': '2R00000409.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000409.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59003'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000380.tif': <File: {'name': '2R00000380.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000380.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59004'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000460.tif': <File: {'name': '2R00000460.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000460.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59005'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000194.tif': <File: {'name': '2R00000194.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000194.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59006'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000469.tif': <File: {'name': '2R00000469.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000469.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59007'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000152.tif': <File: {'name': '2R00000152.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000152.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59008'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000000.tif': <File: {'name': '2R00000000.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000000.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59009'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000312.tif': <File: {'name': '2R00000312.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000312.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59010'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000160.tif': <File: {'name': '2R00000160.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000160.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59011'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000025.tif': <File: {'name': '2R00000025.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000025.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59012'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000525.tif': <File: {'name': '2R00000525.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000525.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59013'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000324.tif': <File: {'name': '2R00000324.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000324.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59014'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000137.tif': <File: {'name': '2R00000137.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000137.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59015'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000146.tif': <File: {'name': '2R00000146.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000146.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59016'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000451.tif': <File: {'name': '2R00000451.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000451.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59017'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000225.tif': <File: {'name': '2R00000225.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000225.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59018'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000507.tif': <File: {'name': '2R00000507.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000507.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59019'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000347.tif': <File: {'name': '2R00000347.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000347.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59020'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000504.tif': <File: {'name': '2R00000504.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000504.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59021'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000142.tif': <File: {'name': '2R00000142.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000142.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59022'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000376.tif': <File: {'name': '2R00000376.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000376.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59023'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000078.tif': <File: {'name': '2R00000078.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000078.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59024'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000298.tif': <File: {'name': '2R00000298.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000298.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59025'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000264.tif': <File: {'name': '2R00000264.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000264.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59026'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000274.tif': <File: {'name': '2R00000274.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000274.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59027'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000413.tif': <File: {'name': '2R00000413.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000413.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59028'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000261.tif': <File: {'name': '2R00000261.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000261.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59029'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000230.tif': <File: {'name': '2R00000230.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000230.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59030'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000154.tif': <File: {'name': '2R00000154.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000154.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59031'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000153.tif': <File: {'name': '2R00000153.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000153.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59032'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000371.tif': <File: {'name': '2R00000371.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000371.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59033'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000021.tif': <File: {'name': '2R00000021.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000021.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59034'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000265.tif': <File: {'name': '2R00000265.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000265.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59035'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000059.tif': <File: {'name': '2R00000059.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000059.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59036'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000125.tif': <File: {'name': '2R00000125.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000125.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59037'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000357.tif': <File: {'name': '2R00000357.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000357.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59038'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000453.tif': <File: {'name': '2R00000453.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000453.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59039'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000410.tif': <File: {'name': '2R00000410.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000410.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59040'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000022.tif': <File: {'name': '2R00000022.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000022.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59041'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000402.tif': <File: {'name': '2R00000402.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000402.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59042'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000354.tif': <File: {'name': '2R00000354.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000354.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59043'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000164.tif': <File: {'name': '2R00000164.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000164.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59044'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000521.tif': <File: {'name': '2R00000521.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000521.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59045'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000314.tif': <File: {'name': '2R00000314.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000314.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59046'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000502.tif': <File: {'name': '2R00000502.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000502.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59047'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000191.tif': <File: {'name': '2R00000191.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000191.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59048'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000421.tif': <File: {'name': '2R00000421.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000421.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59049'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000327.tif': <File: {'name': '2R00000327.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000327.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59050'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000081.tif': <File: {'name': '2R00000081.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000081.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59051'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000433.tif': <File: {'name': '2R00000433.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000433.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59052'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000055.tif': <File: {'name': '2R00000055.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000055.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59053'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000446.tif': <File: {'name': '2R00000446.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000446.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59054'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000177.tif': <File: {'name': '2R00000177.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000177.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59055'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000040.tif': <File: {'name': '2R00000040.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000040.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59056'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000013.tif': <File: {'name': '2R00000013.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000013.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59057'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000277.tif': <File: {'name': '2R00000277.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000277.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59058'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000086.tif': <File: {'name': '2R00000086.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000086.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59059'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000524.tif': <File: {'name': '2R00000524.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000524.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59060'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000508.tif': <File: {'name': '2R00000508.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000508.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59061'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000316.tif': <File: {'name': '2R00000316.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000316.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59062'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000348.tif': <File: {'name': '2R00000348.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000348.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59063'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000359.tif': <File: {'name': '2R00000359.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000359.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59064'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000254.tif': <File: {'name': '2R00000254.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000254.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59065'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000385.tif': <File: {'name': '2R00000385.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000385.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59066'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000509.tif': <File: {'name': '2R00000509.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000509.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59067'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000482.tif': <File: {'name': '2R00000482.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000482.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59068'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000442.tif': <File: {'name': '2R00000442.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000442.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59069'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000272.tif': <File: {'name': '2R00000272.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000272.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59070'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000071.tif': <File: {'name': '2R00000071.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000071.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59071'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000375.tif': <File: {'name': '2R00000375.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000375.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59072'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000547.tif': <File: {'name': '2R00000547.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000547.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59073'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000349.tif': <File: {'name': '2R00000349.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000349.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59074'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000520.tif': <File: {'name': '2R00000520.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000520.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59075'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000257.tif': <File: {'name': '2R00000257.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R00000257.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59076'}>,
# ...
#  'folder_temp': <Folder: {'name': 'temp', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/temp', 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59919'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R_Rec/temp/2R_rec_spr.bmp': <File: {'name': '2R_rec_spr.bmp', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R_Rec/temp/2R_rec_spr.bmp', 'extension': '.bmp', 'size': 678454, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59920'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R_Rec/temp/2R_pp1.tif': <File: {'name': '2R_pp1.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R_Rec/temp/2R_pp1.tif', 'extension': '.tif', 'size': 403806, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59921'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R_Rec/temp/2R_pp2.tif': <File: {'name': '2R_pp2.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R_Rec/temp/2R_pp2.tif', 'extension': '.tif', 'size': 403806, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59922'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R_Rec/temp/2R_rec_spr.tif': <File: {'name': '2R_rec_spr.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R_Rec/temp/2R_rec_spr.tif', 'extension': '.tif', 'size': 1356302, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59923'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R_Rec/temp/2R_rec.log': <File: {'name': '2R_rec.log', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/2R/2R_Rec/temp/2R_rec.log', 'extension': '.log', 'size': 3215, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59924'}>,
#  'System_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/temp': <System: {'name': None, 'Scanner': 'SkyScan1276', 'Instrument S/N': '18F17059', 'Software Version': '1.4', 'Magnification Drive Version': '3.4', 'Camera Drive Version': '3.4', 'Filter  Drive Version': '3.4', 'Animal Drive Version': '3.4', 'Home Directory': 'C:\\SkyScan1276', 'Source Type': 'HAMAMATSU L10321', 'Camera Type': 'XIMEA MH110XC-KK-TP', 'Camera Pixel Size (um)': '17.359', 'Camera X/Y Ratio': '0.9949', 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59925'}>,
#  'scan_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/temp': <Scan: {'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/temp', 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59926'}>,
#  'User_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/temp': <User: {'name': None, 'User Name': 'vspan', 'Computer Name': 'MICROCT', 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59927'}>,
#  'Acquisition_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/temp': <Acquisition: {'name': None, 'Data Directory': 'D:\\Results\\LauraM\\new study\\Scan2\\1L', 'Filename Prefix': '1L', 'Number Of Files': '558', 'Number Of Rows': '672', 'Number Of Columns': '1008', 'Filename Index Length': '8', 'Partial Width': 'OFF', 'Image crop origin X': '0', 'Image crop origin Y': '0', 'Camera binning': '4x4', 'Image Rotation': '0.00000', 'Optical Axis (line)': '346', 'Object to Source (mm)': '92.863', 'Camera to Source (mm)': '160.543', 'Source Voltage (kV)': '100', 'Source Current (uA)': '200', 'Image Pixel Size (um)': '40.164000', 'Scaled Image Pixel Size (um)': '40.164000', 'Image Format': 'TIFF', 'Depth (bits)': '16', 'Reference Intensity': '58000', 'Exposure (ms)': '90', 'Rotation Step (deg)': '0.648', 'Use 360 Rotation': 'YES', 'Scanning position': '241.306 mm', 'Frame Averaging': 'OFF (1)', 'Flat Field Correction': 'ON', 'Random Movement': 'OFF (5)', 'Filter': 'Al 0.5mm', 'Gantry direction': 'CC', 'Rotation Direction': 'CC', 'Intrinsic CS rotation in degree': '180.0', 'Type of Detector Motion': 'CONTINUOUS', 'Rotation speed': '1', 'Scanning Trajectory': 'ROUND', 'Suggested HU - Calibration': '180000', 'Number Of Horizontal Offset Positions': '1', 'Study Date and Time': '25 Sep 2020  13h:09m:23s', 'Scan duration': '0h:1m:16s', 'Maximum vertical TS': '5.0', 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59928'}>,
#  'Reconstruction_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/temp': <Reconstruction: {'name': None, 'Reconstruction Program': 'NRecon', 'Program Version': 'Version: 1.7.4.2', 'Program Home Directory': 'C:\\SkyScan1276', 'Reconstruction engine': 'GPUReconServer', 'Engine version': 'Version: 1.7.4', 'Reconstruction from batch': 'No', 'Postalignment Applied': '1', 'Postalignment': '0.00', 'Reconstruction servers': 'MICROCT', 'Dataset Origin': 'SkyScan1276', 'Dataset Prefix': '1L', 'Dataset Directory': 'D:\\Results\\LauraM\\new study\\Scan2\\1L', 'Output Directory': 'D:\\Results\\LauraM\\new study\\Scan2\\1L\\1L_Rec', 'Time and Date': 'Sep 25, 2020  13:11:16', 'First Section': '183', 'Last Section': '590', 'Reconstruction duration per slice (seconds)': '0.178922', 'Total reconstruction time (411 slices) in seconds': '84.000000', 'Section to Section Step': '1', 'Sections Count': '408', 'Result File Type': 'TIF', 'Result File Header Length (bytes)': '12', 'Result Image Width (pixels)': '664', 'Result Image Height (pixels)': '568', 'Pixel Size (um)': '40.16400', 'Reconstruction Angular Range (deg)': '360.29', 'Use 180+': 'OFF', 'Angular Step (deg)': '0.6480', 'Smoothing': '2', 'Smoothing kernel': '2 (Gaussian)', 'Ring Artifact Correction': '2', 'Draw Scales': 'OFF', 'Object Bigger than FOV': 'ON', 'Reconstruction from ROI': 'ON', 'ROI Top (pixels)': '964', 'ROI Bottom (pixels)': '395', 'ROI Left (pixels)': '210', 'ROI Right (pixels)': '876', 'ROI reference length': '1008', 'Filter cutoff relative to Nyquist frequency': '100', 'Filter type': '0', 'Filter type description': 'Hamming (Alpha=0.54)', 'Undersampling factor': '1', 'Threshold for defect pixel mask (%)': '0', 'Beam Hardening Correction (%)': '33', 'CS Static Rotation (deg)': '0.00', 'CS Static Rotation Total(deg)': '180.00', 'Minimum for CS to Image Conversion': '0.000000', 'Maximum for CS to Image Conversion': '0.015000', 'HU Calibration': 'OFF', 'BMP LUT': '0', 'Cone-beam Angle Horiz.(deg)': '24.594404', 'Cone-beam Angle Vert.(deg)': '16.536995', 'Total reconstruction time (459 slices) in seconds': '48.000000', 'Total reconstruction time (434 slices) in seconds': '56.000000', 'Total reconstruction time (422 slices) in seconds': '53.000000', 'Total reconstruction time (471 slices) in seconds': '94.000000', 'Total reconstruction time (367 slices) in seconds': '25.000000', 'Total reconstruction time (482 slices) in seconds': '47.000000', 'Total reconstruction time (393 slices) in seconds': '31.000000', 'Total reconstruction time (420 slices) in seconds': '37.000000', 'Total reconstruction time (408 slices) in seconds': '73.000000', 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59929'}>,
#  'File name convention_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/temp': <File_name_convention: {'name': None, 'Filename Index Length': '8', 'Filename Prefix': '1L_rec', 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59930'}>,
#  'System_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/2R': <System: {'name': None, 'Scanner': 'SkyScan1276', 'Instrument S/N': '18F17059', 'Software Version': '1.4', 'Magnification Drive Version': '3.4', 'Camera Drive Version': '3.4', 'Filter  Drive Version': '3.4', 'Animal Drive Version': '3.4', 'Home Directory': 'C:\\SkyScan1276', 'Source Type': 'HAMAMATSU L10321', 'Camera Type': 'XIMEA MH110XC-KK-TP', 'Camera Pixel Size (um)': '17.359', 'Camera X/Y Ratio': '0.9949', 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59931'}>,
#  'scan_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/2R': <Scan: {'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/2R', 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59932'}>,
#  'User_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/2R': <User: {'name': None, 'User Name': 'vspan', 'Computer Name': 'MICROCT', 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59933'}>,
#  'Acquisition_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/2R': <Acquisition: {'name': None, 'Data Directory': 'D:\\Results\\LauraM\\new study\\Scan2\\2R', 'Filename Prefix': '2R', 'Number Of Files': '557', 'Number Of Rows': '672', 'Number Of Columns': '1008', 'Filename Index Length': '8', 'Partial Width': 'OFF', 'Image crop origin X': '0', 'Image crop origin Y': '0', 'Camera binning': '4x4', 'Image Rotation': '0.00000', 'Optical Axis (line)': '346', 'Object to Source (mm)': '92.863', 'Camera to Source (mm)': '160.543', 'Source Voltage (kV)': '100', 'Source Current (uA)': '200', 'Image Pixel Size (um)': '40.164000', 'Scaled Image Pixel Size (um)': '40.164000', 'Image Format': 'TIFF', 'Depth (bits)': '16', 'Reference Intensity': '58000', 'Exposure (ms)': '90', 'Rotation Step (deg)': '0.648', 'Use 360 Rotation': 'YES', 'Scanning position': '240.000 mm', 'Frame Averaging': 'OFF (1)', 'Flat Field Correction': 'ON', 'Random Movement': 'OFF (5)', 'Filter': 'Al 0.5mm', 'Gantry direction': 'CC', 'Rotation Direction': 'CC', 'Intrinsic CS rotation in degree': '180.0', 'Type of Detector Motion': 'CONTINUOUS', 'Rotation speed': '1', 'Scanning Trajectory': 'ROUND', 'Suggested HU - Calibration': '180000', 'Number Of Horizontal Offset Positions': '1', 'Study Date and Time': '25 Sep 2020  13h:02m:33s', 'Scan duration': '0h:1m:16s', 'Maximum vertical TS': '5.0', 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59934'}>,
#  'Reconstruction_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/2R': <Reconstruction: {'name': None, 'Reconstruction Program': 'NRecon', 'Program Version': 'Version: 1.7.4.2', 'Program Home Directory': 'C:\\SkyScan1276', 'Reconstruction engine': 'GPUReconServer', 'Engine version': 'Version: 1.7.4', 'Reconstruction from batch': 'No', 'Postalignment Applied': '1', 'Postalignment': '0.50', 'Reconstruction servers': 'MICROCT', 'Dataset Origin': 'SkyScan1276', 'Dataset Prefix': '2R', 'Dataset Directory': 'D:\\Results\\LauraM\\new study\\Scan2\\2R', 'Output Directory': 'D:\\Results\\LauraM\\new study\\Scan2\\2R\\2R_Rec', 'Time and Date': 'Sep 25, 2020  13:03:43', 'First Section': '229', 'Last Section': '595', 'Reconstruction duration per slice (seconds)': '0.068120', 'Total reconstruction time (411 slices) in seconds': '84.000000', 'Section to Section Step': '1', 'Sections Count': '367', 'Result File Type': 'TIF', 'Result File Header Length (bytes)': '12', 'Result Image Width (pixels)': '664', 'Result Image Height (pixels)': '568', 'Pixel Size (um)': '40.16400', 'Reconstruction Angular Range (deg)': '360.29', 'Use 180+': 'OFF', 'Angular Step (deg)': '0.6480', 'Smoothing': '2', 'Smoothing kernel': '2 (Gaussian)', 'Ring Artifact Correction': '2', 'Draw Scales': 'OFF', 'Object Bigger than FOV': 'ON', 'Reconstruction from ROI': 'ON', 'ROI Top (pixels)': '964', 'ROI Bottom (pixels)': '395', 'ROI Left (pixels)': '210', 'ROI Right (pixels)': '876', 'ROI reference length': '1008', 'Filter cutoff relative to Nyquist frequency': '100', 'Filter type': '0', 'Filter type description': 'Hamming (Alpha=0.54)', 'Undersampling factor': '1', 'Threshold for defect pixel mask (%)': '0', 'Beam Hardening Correction (%)': '33', 'CS Static Rotation (deg)': '0.00', 'CS Static Rotation Total(deg)': '180.00', 'Minimum for CS to Image Conversion': '0.000000', 'Maximum for CS to Image Conversion': '0.015000', 'HU Calibration': 'OFF', 'BMP LUT': '0', 'Cone-beam Angle Horiz.(deg)': '24.594404', 'Cone-beam Angle Vert.(deg)': '16.536995', 'Total reconstruction time (367 slices) in seconds': '25.000000', 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59935'}>,
#  'folder_both': <Folder: {'name': 'both', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/both', 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59936'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/both/both00000137.tif': <File: {'name': 'both00000137.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/both/both00000137.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59937'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/both/both00000024.tif': <File: {'name': 'both00000024.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/both/both00000024.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59938'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/both/both00000355.tif': <File: {'name': 'both00000355.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/both/both00000355.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59939'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/both/both00000102.tif': <File: {'name': 'both00000102.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/both/both00000102.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59940'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/both/both00000511.tif': <File: {'name': 'both00000511.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/both/both00000511.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59941'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/both/both00000037.tif': <File: {'name': 'both00000037.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/both/both00000037.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59942'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/both/both00000131.tif': <File: {'name': 'both00000131.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/both/both00000131.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59943'}>,
#  'file_/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/both/both00000149.tif': <File: {'name': 'both00000149.tif', 'filepath': '/home/patch/PycharmProjects/neb4neo/neb4neo/etl/experiment/LaraM new study/Scan1/both/both00000149.tif', 'extension': '.tif', 'size': 1355230, 'element_id_property': '4:31534542-ba07-4b86-8482-b4daf2237641:59944'}>,
#  ...}

# %%
source, target, data = list(G.edges(data=True))[1]

# %%
G.has_node(source)
# Out:
# True

# %%
G.nodes()[source]['label']
# Out:
# 'Folder'

# %%
d[source]['label']
# Out:
# 'Folder'

# %%
for source, target, data in G.edges(data=True):
    print(f"Edge from {source} to {target} with data {data}")
