# %%
from pathlib import Path
import time
import pandas as pd

def collect_file_tree(base_directory):
    base_path = Path(base_directory)
    
    def add_to_tree(path, tree):
        parts = path.relative_to(base_path).parts
        current_tree = tree
        for part in parts[:-1]:
            current_tree = current_tree.setdefault(part, {'type': 'folder', 'size': 0, 'created': None, 'modified': None, 'contents': {}})['contents']
        if path.is_dir():
            stats = path.stat()
            current_tree[parts[-1]] = {
                'type': 'folder',
                'size': 0,  # Placeholder size for folders
                'created': time.ctime(stats.st_ctime),
                'modified': time.ctime(stats.st_mtime),
                'contents': {}
            }
        elif path.is_file():
            stats = path.stat()
            current_tree[parts[-1]] = {
                'type': f'{path.suffix}',
                'size': stats.st_size,
                'created': time.ctime(stats.st_ctime),
                'modified': time.ctime(stats.st_mtime),
                'contents': None
            }

    # Ensure the base directory itself is included
    file_tree = {
        'base': {
            'type': 'folder',
            'size': 0,  # Placeholder size for base directory
            'created': time.ctime(base_path.stat().st_ctime),
            'modified': time.ctime(base_path.stat().st_mtime),
            'contents': {}
        }
    }
    
    for item in base_path.rglob('*'):
        add_to_tree(item, file_tree['base']['contents'])
    
    return file_tree


def list_files(file_tree):
    _l = []
    
    def process_files(tree):
        for _k, _v in tree.items():
            if isinstance(_v, dict) and _v['type'] != 'folder':
                _d = _v.copy()
                _d['name'] = _k
                _l.append(_d)

    process_files(file_tree)
    return pd.DataFrame(_l)

def list_folders(file_tree):
    _l = []

    def folder_size_sum(tree):
        _sum_size = 0
        for _i, _contents in tree.items():
            if isinstance(_contents, dict):
                if _contents['type'] == 'folder':
                    _sum_size += folder_size_sum(_contents['contents'])
                else:
                    _sum_size += _contents['size']
        return _sum_size

    def process_folders(tree):
        for _k, _v in tree.items():
            if isinstance(_v, dict) and 'type' in _v and _v['type'] == 'folder':
                _d = {
                    'type': _v['type'],
                    'size': folder_size_sum(_v['contents']),
                    'created': _v['created'],
                    'modified': _v['modified'],
                    'name': _k
                }
                _l.append(_d)

    process_folders(file_tree)
    return pd.DataFrame(_l)

def list_all(file_tree):
    files_df = list_files(file_tree)
    folders_df = list_folders(file_tree)
    return pd.concat([files_df, folders_df], ignore_index=True)

# %%
# Example usage:
base_directory_path = '.'
file_tree = collect_file_tree(base_directory_path)

# %%
# List files
files_df = list_files(file_tree['base']['contents'])
print("Files:")
files_df
# Out:
# Files:
#       type    size                   created                  modified  \
# 0   .ipynb  458708  Wed May 15 11:26:37 2024  Wed May 15 11:26:37 2024
# 1      .py       0  Wed May 15 11:45:52 2024  Wed May 15 11:45:52 2024
# 2               94  Wed May 15 15:00:25 2024  Wed May 15 15:00:25 2024
# 3   .ipynb   35253  Thu May  9 12:27:29 2024  Thu May  9 12:27:29 2024
# 4   .ipynb    9434  Tue May 14 15:43:05 2024  Tue May 14 15:43:05 2024
# 5      .py    4907  Thu May  9 15:16:11 2024  Thu May  9 15:16:11 2024
# 6      .py    3710  Thu May  9 14:31:15 2024  Thu May  9 14:31:15 2024
# 7   .ipynb   13144  Wed May 15 12:44:31 2024  Wed May 15 12:44:31 2024
# 8      .py    4999  Thu May 16 10:17:58 2024  Thu May 16 10:17:58 2024
# 9   .ipynb   12517  Wed May 15 13:20:36 2024  Wed May 15 13:20:36 2024
# 10  .ipynb   58033  Fri May 17 12:33:56 2024  Fri May 17 12:33:56 2024
# 11  .ipynb   10686  Wed May 15 16:48:19 2024  Wed May 15 16:32:17 2024
# 12     .py    4916  Thu May  9 17:14:31 2024  Thu May  9 17:14:31 2024
# 13     .py    3902  Thu May  9 14:23:09 2024  Thu May  9 14:23:09 2024
# 14  .ipynb   12813  Thu May  2 17:45:17 2024  Thu May  2 17:45:17 2024
# 15  .ipynb  322858  Fri May 17 11:00:16 2024  Fri May 17 11:00:16 2024
#
#    contents                                  name
# 0      None          MicroCT_Filetree_to_KG.ipynb
# 1      None                           __init__.py
# 2      None                            .gitignore
# 3      None        MicroCT_KG_Meta_Analysis.ipynb
# 4      None              CFT_Filetree_to_KG.ipynb
# 5      None  kg_property_summary_microct-Copy3.py
# 6      None  kg_property_summary_microct-Copy2.py
# 7      None                    DICOM_Reader.ipynb
# 8      None        kg_property_summary_microct.py
# 9      None               US_Filetree_to_KG.ipynb
# 10     None                  Filetree_Parse.ipynb
# 11     None             IVIS_Filetree_Parse.ipynb
# 12     None  kg_property_summary_microct-Copy4.py
# 13     None  kg_property_summary_microct-Copy1.py
# 14     None                     TIFF_Reader.ipynb
# 15     None  Demo_Scrape_and_Store_Metadata.ipynb

# %%
# List folders with total size
folders_df = list_folders(file_tree['base']['contents'])
print("Folders:")
folders_df
# Out:
# Folders:
#      type         size                   created                  modified  \
# 0  folder        16024  Mon Nov  6 15:09:25 2023  Mon Nov  6 15:09:25 2023
# 1  folder    865838216  Tue May 14 15:25:54 2024  Tue May 14 15:25:54 2024
# 2  folder  10598002342  Tue May  7 10:37:46 2024  Tue Feb  7 16:12:30 2023
# 3  folder   8984944257  Thu May  2 14:57:15 2024  Thu May  2 13:28:01 2024
# 4  folder        44671  Thu May 16 14:37:12 2024  Thu May 16 14:37:12 2024
# 5  folder      4728462  Thu May  2 12:46:06 2024  Thu May  2 12:45:39 2024
# 6  folder        50720  Mon Nov  6 15:09:25 2023  Mon Nov  6 15:09:25 2023
# 7  folder          337  Wed May 15 11:45:52 2024  Wed May 15 11:45:52 2024
# 8  folder       773145  Fri May 17 12:21:12 2024  Fri May 17 12:21:12 2024
# 9  folder    793597790  Thu May  2 14:57:15 2024  Thu May  2 14:56:40 2024
#
#                         name
# 0                        eda
# 1      US v Caliper analyzed
# 2            LaraM new study
# 3                   LungData
# 4                   filetree
# 5            PancreaticTumor
# 6                intake_form
# 7                __pycache__
# 8         .ipynb_checkpoints
# 9  Example mcroCT tiff files

# %%
# List all files and folders
all_df = list_all(file_tree['base']['contents'])
print("All files and folders:")
all_df
# Out:
# All files and folders:
#       type         size                   created                  modified  \
# 0   .ipynb       458708  Wed May 15 11:26:37 2024  Wed May 15 11:26:37 2024
# 1      .py            0  Wed May 15 11:45:52 2024  Wed May 15 11:45:52 2024
# 2                    94  Wed May 15 15:00:25 2024  Wed May 15 15:00:25 2024
# 3   .ipynb        35253  Thu May  9 12:27:29 2024  Thu May  9 12:27:29 2024
# 4   .ipynb         9434  Tue May 14 15:43:05 2024  Tue May 14 15:43:05 2024
# 5      .py         4907  Thu May  9 15:16:11 2024  Thu May  9 15:16:11 2024
# 6      .py         3710  Thu May  9 14:31:15 2024  Thu May  9 14:31:15 2024
# 7   .ipynb        13144  Wed May 15 12:44:31 2024  Wed May 15 12:44:31 2024
# 8      .py         4999  Thu May 16 10:17:58 2024  Thu May 16 10:17:58 2024
# 9   .ipynb        12517  Wed May 15 13:20:36 2024  Wed May 15 13:20:36 2024
# 10  .ipynb        58033  Fri May 17 12:33:56 2024  Fri May 17 12:33:56 2024
# 11  .ipynb        10686  Wed May 15 16:48:19 2024  Wed May 15 16:32:17 2024
# 12     .py         4916  Thu May  9 17:14:31 2024  Thu May  9 17:14:31 2024
# 13     .py         3902  Thu May  9 14:23:09 2024  Thu May  9 14:23:09 2024
# 14  .ipynb        12813  Thu May  2 17:45:17 2024  Thu May  2 17:45:17 2024
# 15  .ipynb       322858  Fri May 17 11:00:16 2024  Fri May 17 11:00:16 2024
# 16  folder        16024  Mon Nov  6 15:09:25 2023  Mon Nov  6 15:09:25 2023
# 17  folder    865838216  Tue May 14 15:25:54 2024  Tue May 14 15:25:54 2024
# 18  folder  10598002342  Tue May  7 10:37:46 2024  Tue Feb  7 16:12:30 2023
# 19  folder   8984944257  Thu May  2 14:57:15 2024  Thu May  2 13:28:01 2024
# 20  folder        44671  Thu May 16 14:37:12 2024  Thu May 16 14:37:12 2024
# 21  folder      4728462  Thu May  2 12:46:06 2024  Thu May  2 12:45:39 2024
# 22  folder        50720  Mon Nov  6 15:09:25 2023  Mon Nov  6 15:09:25 2023
# 23  folder          337  Wed May 15 11:45:52 2024  Wed May 15 11:45:52 2024
# 24  folder       773145  Fri May 17 12:21:12 2024  Fri May 17 12:21:12 2024
# 25  folder    793597790  Thu May  2 14:57:15 2024  Thu May  2 14:56:40 2024
#
#    contents                                  name
# 0      None          MicroCT_Filetree_to_KG.ipynb
# 1      None                           __init__.py
# 2      None                            .gitignore
# 3      None        MicroCT_KG_Meta_Analysis.ipynb
# 4      None              CFT_Filetree_to_KG.ipynb
# 5      None  kg_property_summary_microct-Copy3.py
# 6      None  kg_property_summary_microct-Copy2.py
# 7      None                    DICOM_Reader.ipynb
# 8      None        kg_property_summary_microct.py
# 9      None               US_Filetree_to_KG.ipynb
# 10     None                  Filetree_Parse.ipynb
# 11     None             IVIS_Filetree_Parse.ipynb
# 12     None  kg_property_summary_microct-Copy4.py
# 13     None  kg_property_summary_microct-Copy1.py
# 14     None                     TIFF_Reader.ipynb
# 15     None  Demo_Scrape_and_Store_Metadata.ipynb
# 16      NaN                                   eda
# 17      NaN                 US v Caliper analyzed
# 18      NaN                       LaraM new study
# 19      NaN                              LungData
# 20      NaN                              filetree
# 21      NaN                       PancreaticTumor
# 22      NaN                           intake_form
# 23      NaN                           __pycache__
# 24      NaN                    .ipynb_checkpoints
# 25      NaN             Example mcroCT tiff files

# %%
list_folders(file_tree)
# Out:
#       type         size                   created                  modified  \
# 0   folder        16024  Mon Nov  6 15:09:25 2023  Mon Nov  6 15:09:25 2023
# 1   folder        16024  Wed Jun 14 14:33:30 2023  Wed Jun 14 14:33:30 2023
# 2   folder    865838216  Tue May 14 15:25:54 2024  Tue May 14 15:25:54 2024
# 3   folder         2084  Tue May 14 15:55:04 2024  Tue May 14 15:55:04 2024
# 4   folder    865833551  Tue May 14 16:16:08 2024  Tue May 14 16:16:08 2024
# 5   folder       357292  Tue May 14 16:20:52 2024  Tue May 14 16:20:52 2024
# 6   folder  10598002342  Tue May  7 10:37:46 2024  Tue Feb  7 16:12:30 2023
# 7   folder   5236700074  Tue May  7 10:37:46 2024  Tue Feb  7 16:12
Mon Nov  6 15:09:25 2023  Mon Nov  6 15:09:25 2023
# 47  folder        17315  Mon Nov  6 15:09:25 2023  Mon Nov  6 15:09:25 2023
# 48  folder        17315  Wed Jun 28 16:15:52 2023  Wed Jun 28 16:15:52 2023
# 49  folder        20897  Thu Jun 29 14:52:11 2023  Thu Jun 29 14:52:11 2023
# 50  folder        12508  Thu Jun 29 14:05:36 2023  Thu Jun 29 14:05:36 2023
# 51  folder          337  Wed May 15 11:45:52 2024  Wed May 15 11:45:52 2024
# 52  folder       722883  Fri May 17 12:21:12 2024  Fri May 17 12:21:12 2024
# 53  folder    793597790  Thu May  2 14:57:15 2024  Thu May  2 14:56:40 2024
#
#                                                  name
# 0                                                 eda
# 1                                     eda/__pycache__
# 2                               US v Caliper analyzed
# 3            US v Caliper analyzed/.ipynb_checkpoints
# 4             US v Caliper analyzed/20211110180827403
# 5   US v Caliper analyzed/20211110180827403/.ipynb...
# 6                                     LaraM new study
# 7                               LaraM new study/Scan1
# 8                            LaraM new study/Scan1/2R
# 9                     LaraM new study/Scan1/2R/2R_Rec
# 10               LaraM new study/Scan1/2R/2R_Rec/temp
# 11                         LaraM new study/Scan1/both
# 12                LaraM new study/Scan1/both/both_Rec
# 13           LaraM new study/Scan1/both/both_Rec/temp
# 14                         LaraM new study/Scan1/none
# 15                LaraM new study/Scan1/none/none_Rec
# 16           LaraM new study/Scan1/none/none_Rec/temp
# 17                           LaraM new study/Scan1/1R
# 18                    LaraM new study/Scan1/1R/1R_Rec
# 19               LaraM new study/Scan1/1R/1R_Rec/temp
# 20                           LaraM new study/Scan1/1L
# 21                    LaraM new study/Scan1/1L/1L_Rec
# 22               LaraM new study/Scan1/1L/1L_Rec/temp
# 23        LaraM new study/Scan1/1L/.ipynb_checkpoints
# 24                              LaraM new study/Scan2
# 25                           LaraM new study/Scan2/2R
# 26                    LaraM new study/Scan2/2R/2R_Rec
# 27               LaraM new study/Scan2/2R/2R_Rec/temp
# 28                           LaraM new study/Scan2/1R
# 29                    LaraM new study/Scan2/1R/1R_Rec
# 30               LaraM new study/Scan2/1R/1R_Rec/temp
# 31                         LaraM new study/Scan2/Both
# 32                LaraM new study/Scan2/Both/Both_Rec
# 33           LaraM new study/Scan2/Both/Both_Rec/temp
# 34                         LaraM new study/Scan2/None
# 35                LaraM new study/Scan2/None/None_Rec
# 36           LaraM new study/Scan2/None/None_Rec/temp
# 37                           LaraM new study/Scan2/1L
# 38                    LaraM new study/Scan2/1L/1L_Rec
# 39               LaraM new study/Scan2/1L/1L_Rec/temp
# 40                                           LungData
# 41                                           filetree
# 42                                     filetree/parse
# 43                         filetree/parse/__pycache__
# 44                               filetree/__pycache__
# 45                                    PancreaticTumor
# 46                                        intake_form
# 47                                 intake_form/schema
# 48              intake_form/schema/.ipynb_checkpoints
# 49                            intake_form/__pycache__
# 50                     intake_form/.ipynb_checkpoints
# 51                                        __pycache__
# 52                                 .ipynb_checkpoints
# 53                          Example mcroCT tiff files

# %%
def get_directory_contents(file_tree, path):
    parts = path.split('/')
    current_tree = file_tree
    for part in parts:
        if part in current_tree:
            current_tree = current_tree[part]['contents']
        else:
            raise ValueError(f"Path '{path}' not found in the directory structure.")
    return current_tree

# %%
get_directory_contents(file_tree, 'base/LaraM new study/Scan1').keys()
# Out:
# dict_keys(['2R', 'both', 'none', '1R', '1L'])

# %%
# Example usage:
base_directory_path = '.'
file_tree = collect_file_tree(base_directory_path)

# Get contents of the base directory
base_contents = get_directory_contents(file_tree, 'base')

# List files in the base directory
files_df = list_files(base_contents)
print("Files in base directory:")
print(files_df)

# List folders in the base directory
folders_df = list_folders(base_contents)
print("Folders in base directory:")
print(folders_df)

# List all files and folders in the base directory
all_df = list_all(base_contents)
print("All files and folders in base directory:")
print(all_df)

# Get contents of a subdirectory (e.g., 'base/folder_name')
subfolder_contents = get_directory_contents(file_tree, 'base/folder_name')

# List files in the subdirectory
files_df = list_files(subfolder_contents)
print("Files in subdirectory:")
print(files_df)

# List folders in the subdirectory
folders_df = list_folders(subfolder_contents)
print("Folders in subdirectory:")
print(folders_df)

# List all files and folders in the subdirectory
all_df = list_all(subfolder_contents)
print("All files and folders in subdirectory:")
print(all_df)
# Out:
# Files in base directory:
#       type    size                   created                  modified  \
# 0   .ipynb  458708  Wed May 15 11:26:37 2024  Wed May 15 11:26:37 2024
# 1      .py       0  Wed May 15 11:45:52 2024  Wed May 15 11:45:52 2024
# 2               94  Wed May 15 15:00:25 2024  Wed May 15 15:00:25 2024
# 3   .ipynb   35253  Thu May  9 12:27:29 2024  Thu May  9 12:27:29 2024
# 4   .ipynb    9434  Tue May 14 15:43:05 2024  Tue May 14 15:43:05 2024
# 5      .py    4907  Thu May  9 15:16:11 2024  Thu May  9 15:16:11 2024
# 6      .py    3710  Thu May  9 14:31:15 2024  Thu May  9 14:31:15 2024
# 7   .ipynb   13144  Wed May 15 12:44:31 2024  Wed May 15 12:44:31 2024
# 8      .py    4999  Thu May 16 10:17:58 2024  Thu May 16 10:17:58 2024
# 9   .ipynb   12517  Wed May 15 13:20:36 2024  Wed May 15 13:20:36 2024
# 10  .ipynb   80102  Fri May 17 12:37:57 2024  Fri May 17 12:37:57 2024
# 11  .ipynb   10686  Wed May 15 16:48:19 2024  Wed May 15 16:32:17 2024
# 12     .py    4916  Thu May  9 17:14:31 2024  Thu May  9 17:14:31 2024
# 13     .py    3902  Thu May  9 14:23:09 2024  Thu May  9 14:23:09 2024
# 14  .ipynb   12813  Thu May  2 17:45:17 2024  Thu May  2 17:45:17 2024
# 15  .ipynb  322858  Fri May 17 11:00:16 2024  Fri May 17 11:00:16 2024
#
#    contents                                  name
# 0      None          MicroCT_Filetree_to_KG.ipynb
# 1      None                           __init__.py
# 2      None                            .gitignore
# 3      None        MicroCT_KG_Meta_Analysis.ipynb
# 4      None              CFT_Filetree_to_KG.ipynb
# 5      None  kg_property_summary_microct-Copy3.py
# 6      None  kg_property_summary_microct-Copy2.py
# 7      None                    DICOM_Reader.ipynb
# 8      None        kg_property_summary_microct.py
# 9      None               US_Filetree_to_KG.ipynb
# 10     None                  Filetree_Parse.ipynb
# 11     None             IVIS_Filetree_Parse.ipynb
# 12     None  kg_property_summary_microct-Copy4.py
# 13     None  kg_property_summary_microct-Copy1.py
# 14     None                     TIFF_Reader.ipynb
# 15     None  Demo_Scrape_and_Store_Metadata.ipynb
# Folders in base directory:
#      type         size                   created                  modified  \
# 0  folder        16024  Mon Nov  6 15:09:25 2023  Mon Nov  6 15:09:25 2023
#
# 8      None        kg_property_summary_microct.py
# 9      None               US_Filetree_to_KG.ipynb
# 10     None                  Filetree_Parse.ipynb
# 11     None             IVIS_Filetree_Parse.ipynb
# 12     None  kg_property_summary_microct-Copy4.py
# 13     None  kg_property_summary_microct-Copy1.py
# 14     None                     TIFF_Reader.ipynb
# 15     None  Demo_Scrape_and_Store_Metadata.ipynb
# 16      NaN                                   eda
# 17      NaN                 US v Caliper analyzed
# 18      NaN                       LaraM new study
# 19      NaN                              LungData
# 20      NaN                              filetree
# 21      NaN                       PancreaticTumor
# 22      NaN                           intake_form
# 23      NaN                           __pycache__
# 24      NaN                    .ipynb_checkpoints
# 25      NaN             Example mcroCT tiff files
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [8], in <cell line: 24>()
#      21 print(all_df)
#      23 # Get contents of a subdirectory (e.g., 'base/folder_name')
# ---> 24 subfolder_contents = get_directory_contents(file_tree, 'base/folder_name')
#      26 # List files in the subdirectory
#      27 files_df = list_files(subfolder_contents)
#
# Input In [7], in get_directory_contents(file_tree, path)
#       6         current_tree = current_tree[part]['contents']
#       7     else:
# ----> 8         raise ValueError(f"Path '{path}' not found in the directory structure.")
#       9 return current_tree
#
# ValueError: Path 'base/folder_name' not found in the directory structure.

# %%
from pathlib import Path
import time
import pandas as pd


def list_files(file_tree):
    _l = []
    for _k, _v in file_tree.items():
        if _v['type'] != 'folder':
            _d = _v.copy()
            _d['name'] = _k
            _l.append(_d)
    return pd.DataFrame(_l)


def list_folders(file_tree):
    _l = []

    def folder_size_sum(tree):
        _sum_size = 0
        for _i, _contents in tree.items():
            if isinstance(_contents, dict) and 'type' in _contents:
                if _contents['type'] == 'folder':
                    _sum_size += folder_size_sum(_contents)
                else:
                    _sum_size += _contents['size']
        return _sum_size

    def process_folders(tree, path=""):
        for _k, _v in tree.items():
            if isinstance(_v, dict) and 'type' in _v and _v['type'] == 'folder':
                if path == "":
                    folder_path = f"{path}/{_k}" if path else _k
                    _d = {
                        'type': _v['type'],
                        'size': folder_size_sum(_v),
                        'created': _v['created'],
                        'modified': _v['modified'],
                        'name': folder_path
                    }
                    _l.append(_d)

    process_folders(file_tree)
    return pd.DataFrame(_l)


def list_all(file_tree):
    files_df = list_files(file_tree)
    folders_df = list_folders(file_tree)
    return pd.concat([files_df, folders_df], ignore_index=True)


def collect_file_tree(base_directory):
    base_path = Path(base_directory)
    
    def add_to_tree(path, tree):
        parts = path.relative_to(base_path).parts
        for part in parts[:-1]:
            tree = tree.setdefault(part, {})
        if path.is_dir():
            stats = path.stat()
            tree[parts[-1]] = {
                'type': 'folder',
                'size': 0,
                'created': time.ctime(stats.st_ctime),
                'modified': time.ctime(stats.st_mtime)
            }
        elif path.is_file():
            stats = path.stat()
            tree[parts[-1]] = {
                'type': f'{path.suffix}',
                'size': stats.st_size,
                'created': time.ctime(stats.st_ctime),
                'modified': time.ctime(stats.st_mtime)
            }

    file_tree = {}
    
    for item in base_path.rglob('*'):
        add_to_tree(item, file_tree)
    
    return file_tree

# %%
base_directory_path = '.'
file_tree = collect_file_tree(base_directory_path)

files_df = list_files(file_tree)
folders_df = list_folders(file_tree)
all_df = list_all(file_tree)

# %%
all_df.sort_values(by=['type','name'], ascending=False).head()
# Out:
#       type       size                   created                  modified  \
# 22  folder      50720  Mon Nov  6 15:09:25 2023  Mon Nov  6 15:09:25 2023
# 20  folder      44671  Thu May 16 14:37:12 2024  Thu May 16 14:37:12 2024
# 16  folder      16024  Mon Nov  6 15:09:25 2023  Mon Nov  6 15:09:25 2023
# 23  folder        337  Wed May 15 11:45:52 2024  Wed May 15 11:45:52 2024
# 17  folder  865838216  Tue May 14 15:25:54 2024  Tue May 14 15:25:54 2024
#
#                      name
# 22            intake_form
# 20               filetree
# 16                    eda
# 23            __pycache__
# 17  US v Caliper analyzed

# %%
folders_df.head()
# Out:
#      type         size                   created                  modified  \
# 0  folder        16024  Mon Nov  6 15:09:25 2023  Mon Nov  6 15:09:25 2023
# 1  folder    865838216  Tue May 14 15:25:54 2024  Tue May 14 15:25:54 2024
# 2  folder  10598002342  Tue May  7 10:37:46 2024  Tue Feb  7 16:12:30 2023
# 3  folder   8984944257  Thu May  2 14:57:15 2024  Thu May  2 13:28:01 2024
# 4  folder        44671  Thu May 16 14:37:12 2024  Thu May 16 14:37:12 2024
#
#                     name
# 0                    eda
# 1  US v Caliper analyzed
# 2        LaraM new study
# 3               LungData
# 4               filetree

# %%
files_df.sort_values(by='modified').head()
# Out:
#       type    size                   created                  modified  \
# 15  .ipynb  322858  Fri May 17 11:00:16 2024  Fri May 17 11:00:16 2024
# 11  .ipynb   18573  Fri May 17 12:20:18 2024  Fri May 17 12:20:18 2024
# 14  .ipynb   12813  Thu May  2 17:45:17 2024  Thu May  2 17:45:17 2024
# 3   .ipynb   35253  Thu May  9 12:27:29 2024  Thu May  9 12:27:29 2024
# 13     .py    3902  Thu May  9 14:23:09 2024  Thu May  9 14:23:09 2024
#
#                                     name
# 15  Demo_Scrape_and_Store_Metadata.ipynb
# 11                        Untitled.ipynb
# 14                     TIFF_Reader.ipynb
# 3         MicroCT_KG_Meta_Analysis.ipynb
# 13  kg_property_summary_microct-Copy1.py

# %%
list_folders(file_tree['intake_form']).sort_values(['type', 'name'], ascending=False).reset_index(drop=True).head()
# Out:
#      type   size                   created                  modified  \
# 0  folder  17315  Mon Nov  6 15:09:25 2023  Mon Nov  6 15:09:25 2023
# 1  folder  20897  Thu Jun 29 14:52:11 2023  Thu Jun 29 14:52:11 2023
# 2  folder  12508  Thu Jun 29 14:05:36 2023  Thu Jun 29 14:05:36 2023
#
#                  name
# 0              schema
# 1         __pycache__
# 2  .ipynb_checkpoints

# %%
file_tree.keys()
# Out:
# dict_keys(['MicroCT_Filetree_to_KG.ipynb', '__init__.py', 'eda', '.gitignore', 'MicroCT_KG_Meta_Analysis.ipynb', 'US v Caliper analyzed', 'CFT_Filetree_to_KG.ipynb', 'LaraM new study', 'LungData', 'kg_property_summary_microct-Copy3.py', 'kg_property_summary_microct-Copy2.py', 'filetree', 'DICOM_Reader.ipynb', 'kg_property_summary_microct.py', 'US_Filetree_to_KG.ipynb', 'PancreaticTumor', 'intake_form', '__pycache__', '.ipynb_checkpoints', 'IVIS_Filetree_Parse.ipynb', 'Untitled.ipynb', 'kg_property_summary_microct-Copy4.py', 'Example mcroCT tiff files', 'kg_property_summary_microct-Copy1.py', 'TIFF_Reader.ipynb', 'Demo_Scrape_and_Store_Metadata.ipynb'])
